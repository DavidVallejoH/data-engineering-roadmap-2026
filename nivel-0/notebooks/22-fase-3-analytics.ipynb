# %%
# %load_ext sql
# %sql postgresql://postgres:changeme1234@localhost:5432/ny_taxi
# Out:
# Connecting to 'postgresql://postgres:***@localhost:5432/ny_taxi'

# %%
# %%sql
# SELECT
#     COUNT(*) AS total_trips,
#     MIN(pickup_datetime) AS min_pickup,
#     MAX(pickup_datetime) AS max_pickup
# FROM curated.trip;
# Out:
# Running query in 'postgresql://postgres:***@localhost:5432/ny_taxi'
# 1 rows affected.
# +-------------+---------------------+---------------------+
# | total_trips |      min_pickup     |      max_pickup     |
# +-------------+---------------------+---------------------+
# |   2964624   | 2002-12-31 22:59:39 | 2024-02-01 00:01:15 |
# +-------------+---------------------+---------------------+

# %%
# %%sql
# SELECT COUNT(*) AS outliers_before_2024
# FROM curated.trip
# WHERE pickup_datetime < '2024-01-01';
# Out:
# Running query in 'postgresql://postgres:***@localhost:5432/ny_taxi'
# 1 rows affected.
# +----------------------+
# | outliers_before_2024 |
# +----------------------+
# |          15          |
# +----------------------+

# %%
# %%sql
# SELECT
#     DATE(pickup_datetime) AS day,
#     SUM(total_amount) AS revenue,
#     COUNT(*) AS trips
# FROM curated.trip
# GROUP BY day
# ORDER BY day
# LIMIT 10;
# Out:
# Running query in 'postgresql://postgres:***@localhost:5432/ny_taxi'
# 10 rows affected.
# +------------+------------+--------+
# |    day     |  revenue   | trips  |
# +------------+------------+--------+
# | 2002-12-31 |    0.0     |   2    |
# | 2009-01-01 |   127.69   |   3    |
# | 2023-12-31 |   224.62   |   10   |
# | 2024-01-01 | 2442843.25 | 81013  |
# | 2024-01-02 | 2282196.02 | 75519  |
# | 2024-01-03 | 2357588.48 | 82427  |
# | 2024-01-04 | 2800511.06 | 102901 |
# | 2024-01-05 | 2728672.52 | 103178 |
# | 2024-01-06 | 2436272.32 | 97117  |
# | 2024-01-07 | 1898102.16 | 67543  |
# +------------+------------+--------+
# Truncated to displaylimit of 10.

# %%
# %%sql
# CREATE INDEX idx_trip_pickup_datetime
# ON curated.trip (pickup_datetime);
# Out:
# Running query in 'postgresql://postgres:***@localhost:5432/ny_taxi'
# ++
# ||
# ++
# ++

# %%
# %%sql
# EXPLAIN ANALYZE
# SELECT * FROM curated.trip
# WHERE pickup_datetime >= '2024-01-15';
# Out:
# Running query in 'postgresql://postgres:***@localhost:5432/ny_taxi'
# 5 rows affected.
# +------------------------------------------------------------------------------------------------------------------+
# |                                                    QUERY PLAN                                                    |
# +------------------------------------------------------------------------------------------------------------------+
# | Seq Scan on trip  (cost=0.00..69440.80 rows=1676241 width=54) (actual time=94.178..254.300 rows=1678072 loops=1) |
# |                  Filter: (pickup_datetime >= '2024-01-15 00:00:00'::timestamp without time zone)                 |
# |                                          Rows Removed by Filter: 1286552                                         |
# |                                             Planning Time: 0.261 ms                                              |
# |                                            Execution Time: 313.505 ms                                            |
# +------------------------------------------------------------------------------------------------------------------+

# %%
# %%sql
# EXPLAIN ANALYZE
# SELECT * FROM curated.trip
# WHERE pickup_datetime = '2024-01-15 08:00:00';
# Out:
# Running query in 'postgresql://postgres:***@localhost:5432/ny_taxi'
# 4 rows affected.
# +--------------------------------------------------------------------------------------------------------------------------------+
# |                                                           QUERY PLAN                                                           |
# +--------------------------------------------------------------------------------------------------------------------------------+
# | Index Scan using idx_trip_pickup_datetime on trip  (cost=0.43..9.83 rows=3 width=54) (actual time=0.048..0.048 rows=0 loops=1) |
# |                        Index Cond: (pickup_datetime = '2024-01-15 08:00:00'::timestamp without time zone)                      |
# |                                                    Planning Time: 0.102 ms                                                     |
# |                                                    Execution Time: 0.064 ms                                                    |
# +--------------------------------------------------------------------------------------------------------------------------------+

# %%
# %%sql
# SELECT indexname, indexdef FROM pg_indexes
# WHERE schemaname = 'curated' AND tablename = 'trip';
# Out:
# Running query in 'postgresql://postgres:***@localhost:5432/ny_taxi'
# 2 rows affected.
# +--------------------------+-------------------------------------------------------------------------------------+
# |        indexname         |                                       indexdef                                      |
# +--------------------------+-------------------------------------------------------------------------------------+
# |        trip_pkey         |         CREATE UNIQUE INDEX trip_pkey ON curated.trip USING btree (trip_id)         |
# | idx_trip_pickup_datetime | CREATE INDEX idx_trip_pickup_datetime ON curated.trip USING btree (pickup_datetime) |
# +--------------------------+-------------------------------------------------------------------------------------+
